# %%
import numpy as np
from sklearn.datasets import load_boston
from sklearn.utils import shuffle, resample

# %%
def topological_sort(feed_dict):
    """
    Sort generic nodes in topological order using Kahn's Algorithm.

    `feed_dict`: A dictionary where the key is a `Input` node and the value is the respective value feed to that node.

    Returns a list of sorted nodes.
    """
    input_nodes = [n for n in feed_dict.keys()]

    G = {}
    nodes = [n for n in input_nodes]
    while len(nodes) > 0:
        n = nodes.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.outbound_nodes:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            nodes.append(m)

    L = []
    S = set(input_nodes)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Input):
            n.value = feed_dict[n]

        L.append(n)
        for m in n.outbound_nodes:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            # if no other incoming edges add to S
            if len(G[m]['in']) == 0:
                S.add(m)
    return L


def forward_and_backward(graph):
    """
    Performs a forward pass through a list of sorted nodes.

    Arguments:

        `output_node`: A node in the graph, should be the output node (have no outgoing edges).
        `sorted_nodes`: A topologically sorted list of nodes.

    Returns the output Node's value
    """

    for n in graph:
        n.forward()
        
    for n in graph[::-1]:
        n.backward()

# %%
class Node(object):
    def __init__(self, inbound_nodes=[]):
        """
        Node's constructor (runs when the object is instantiated). Sets
        properties that all nodes need.
        """
        # properties
        self.inbound_nodes = inbound_nodes
        self.value = None
        self.outbound_nodes = []
        self.gradients = {}
        for node in inbound_nodes:
            node.outbound_nodes.append(self)
            
        self.value = None
    
    def forward(self):
        """
        Forward propagation.

        Compute the output value based on `inbound_nodes` and
        store the result in self.value.
        """
        raise NotImplemented
        
    def backward(self):
        """
        Every node that uses this class as a base class will
        need to define its own `backward` method.
        """
        raise NotImplementedError

# %%
class Input(Node):
    def __init__(self):
        # An Input node has no inbound nodes,
        # so no need to pass anything to the Node instantiator.
        Node.__init__(self)
        
    def forward(self, value=None):
        pass

    def backward(self):
        self.gradients = {self: 0}
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            self.gradients[self] += grad_cost * 1

# %%
class Add(Node):
    def __init__(self, x, y):
        Node.__init__(self, [x, y])
        
    def forward(self):
        x, y = self.inbound_nodes
        self.value = x.value + y.value

# %%
class Linear(Node):
    def __init__(self, X, Y, b):
        Node.__init__(self, [X, Y, b])
        
    def forward(self):
        x, y, z = self.inbound_nodes
        self.value = np.dot(x.value, y.value) + z.value
        
    def backward(self):
        """
        Calculates the gradient based on the output values.
        """
        # Initialize a partial for each of the inbound_nodes.
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            inputs, weights, bias = self.inbound_nodes
            self.gradients[inputs] += np.dot(grad_cost, self.inbound_nodes[1].value.T)
            self.gradients[weights] += np.dot(self.inbound_nodes[0].value.T, grad_cost)
            self.gradients[bias] += np.sum(grad_cost, axis=0, keepdims=False)

# %%
class Sigmoid(Node):
    def __init__(self, node):
        Node.__init__(self, [node])
        
    def _sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    
    def forward(self):
        linear = self.inbound_nodes[0].value
        self.value = self._sigmoid(linear)
    
    def backward(self):
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            inputs = self.inbound_nodes[0]
            self.gradients[inputs] += self.value * (1 - self.value) * grad_cost

# %%
class MSE(Node):
    def __init__(self, y, a):
        Node.__init__(self, [y, a])
        
    def forward(self):
        """
        Calculates the mean squared error.
        NOTE: We reshape these to avoid possible matrix/vector broadcast
        errors.
        
        For example, if we subtract an array of shape (3,) from an array of shape
        (3,1) we get an array of shape(3,3) as the result when we want
        an array of shape (3,1) instead.
        
        Making both arrays (3,1) insures the result is (3,1) and does
        an elementwise subtraction as expected.
        """
        self.m = self.inbound_nodes[0].value.shape[0]

        y = self.inbound_nodes[0].value.reshape(-1, 1)
        a = self.inbound_nodes[1].value.reshape(-1, 1)
        self.diff = y - a
        self.value = 1/len(y) * np.sum(np.square(self.diff))
        
    def backward(self):
        self.gradients[self.inbound_nodes[0]] = (2 / self.m) * self.diff
        self.gradients[self.inbound_nodes[1]] = (-2 / self.m) * self.diff

# %%
def sgd_update(trainables, learning_rate=1e-2):
    """
    Updates the value of each trainable with SGD.

    Arguments:

        `trainables`: A list of `Input` Nodes representing weights/biases.
        `learning_rate`: The learning rate.
    """
    for t in trainables:
        t.value -= (learning_rate * t.gradients[t] )

# %%
# Load data
data = load_boston()
X_ = data['data']
y_ = data['target']

# Normalize data
X_ = (X_ - np.mean(X_, axis=0)) / np.std(X_, axis=0)

n_features = X_.shape[1]
n_hidden = 10
W1_ = np.random.randn(n_features, n_hidden)
b1_ = np.zeros(n_hidden)
W2_ = np.random.randn(n_hidden, 1)
b2_ = np.zeros(1)

# Neural network
X, y = Input(), Input()
W1, b1 = Input(), Input()
W2, b2 = Input(), Input()

l1 = Linear(X, W1, b1)
s1 = Sigmoid(l1)
l2 = Linear(s1, W2, b2)
cost = MSE(y, l2)

feed_dict = {
    X: X_,
    y: y_,
    W1: W1_,
    b1: b1_,
    W2: W2_,
    b2: b2_
}

epochs = 1000
# Total number of examples
m = X_.shape[0]
batch_size = 11
steps_per_epoch = m // batch_size

graph = topological_sort(feed_dict)
trainables = [W1, b1, W2, b2]

print("Total number of examples = {}".format(m))

# Step 4
for i in range(epochs):
    loss = 0
    for j in range(steps_per_epoch):
        # Step 1
        # Randomly sample a batch of examples
        X_batch, y_batch = resample(X_, y_, n_samples=batch_size)

        # Reset value of X and y Inputs
        X.value = X_batch
        y.value = y_batch

        # Step 2
        forward_and_backward(graph)

        # Step 3
        sgd_update(trainables)

        loss += graph[-1].value

    print("Epoch: {}, Loss: {:.3f}".format(i+1, loss/steps_per_epoch))
# Out:
# Total number of examples = 506
# Epoch: 1, Loss: 99.645
# Epoch: 2, Loss: 33.963
# Epoch: 3, Loss: 29.872
# Epoch: 4, Loss: 20.862
# Epoch: 5, Loss: 26.198
# Epoch: 6, Loss: 17.409
# Epoch: 7, Loss: 14.757
# Epoch: 8, Loss: 14.474
# Epoch: 9, Loss: 16.627
# Epoch: 10, Loss: 10.987
# Epoch: 11, Loss: 15.670
# Epoch: 12, Loss: 13.906
# Epoch: 13, Loss: 12.232
# Epoch: 14, Loss: 11.291
# Epoch: 15, Loss: 12.765
# Epoch: 16, Loss: 10.976
# Epoch: 17, Loss: 9.596
# Epoch: 18, Loss: 9.705
# Epoch: 19, Loss: 11.328
# Epoch: 20, Loss: 10.716
# Epoch: 21, Loss: 10.786
# Epoch: 22, Loss: 11.713
# Epoch: 23, Loss: 8.631
# Epoch: 24, Loss: 11.574
# Epoch: 25, Loss: 9.300
# Epoch: 26, Loss: 9.142
# Epoch: 27, Loss: 10.763
# Epoch: 28, Loss: 9.986
# Epoch: 29, Loss: 9.185
# Epoch: 30, Loss: 8.193
# Epoch: 31, Loss: 7.732
# Epoch: 32, Loss: 7.779
# Epoch: 33, Loss: 9.617
# Epoch: 34, Loss: 6.978
# Epoch: 35, Loss: 8.512
# Epoch: 36, Loss: 8.258
# Epoch: 37, Loss: 7.267
# Epoch: 38, Loss: 9.429
# Epoch: 39, Loss: 8.652
# Epoch: 40, Loss: 8.137
# Epoch: 41, Loss: 7.778
# Epoch: 42, Loss: 7.070
# Epoch: 43, Loss: 8.458
# Epoch: 44, Loss: 8.554
# Epoch: 45, Loss: 7.258
# Epoch: 46, Loss: 7.635
# Epoch: 47, Loss: 7.345
# Epoch: 48, Loss: 7.056
# Epoch: 49, Loss: 6.815
# Epoch: 50, Loss: 6.433
# Epoch: 51, Loss: 9.411
# Epoch: 52, Loss: 7.279
# Epoch: 53, Loss: 8.594
# Epoch: 54, Loss: 7.609
# Epoch: 55, Loss: 7.424
# Epoch: 56, Loss: 6.224
# Epoch: 57, Loss: 8.513
# Epoch: 58, Loss: 7.297
# Epoch: 59, Loss: 7.194
# Epoch: 60, Loss: 6.364
# Epoch: 61, Loss: 7.240
# Epoch: 62, Loss: 6.889
# Epoch: 63, Loss: 7.469
# Epoch: 64, Loss: 7.243
# Epoch: 65, Loss: 7.838
# Epoch: 66, Loss: 6.814
# Epoch: 67, Loss: 7.294
# Epoch: 68, Loss: 6.717
# Epoch: 69, Loss: 7.163
# Epoch: 70, Loss: 6.457
# Epoch: 71, Loss: 5.472
# Epoch: 72, Loss: 5.976
# Epoch: 73, Loss: 5.572
# Epoch: 74, Loss: 5.744
# Epoch: 75, Loss: 5.396
# Epoch: 76, Loss: 5.859
# Epoch: 77, Loss: 6.936
# Epoch: 78, Loss: 5.035
# Epoch: 79, Loss: 6.764
# Epoch: 80, Loss: 5.404
# Epoch: 81, Loss: 5.572
# Epoch: 82, Loss: 5.058
# Epoch: 83, Loss: 6.407
# Epoch: 84, Loss: 6.212
# Epoch: 85, Loss: 6.017
# Epoch: 86, Loss: 5.731
# Epoch: 87, Loss: 5.621
# Epoch: 88, Loss: 4.971
# Epoch: 89, Loss: 5.286
# Epoch: 90, Loss: 5.796
# Epoch: 91, Loss: 4.996
# Epoch: 92, Loss: 5.554
# Epoch: 93, Loss: 5.655
# Epoch: 94, Loss: 5.448
# Epoch: 95, Loss: 6.102
# Epoch: 96, Loss: 4.663
# Epoch: 97, Loss: 6.491
# Epoch: 98, Loss: 5.157
# Epoch: 99, Loss: 6.499
# Epoch: 100, Loss: 5.483
# Epoch: 101, Loss: 6.617
# Epoch: 102, Loss: 4.997
# Epoch: 103, Loss: 5.753
# Epoch: 104, Loss: 6.414
# Epoch: 105, Loss: 5.993
# Epoch: 106, Loss: 6.572
# Epoch: 107, Loss: 5.821
# Epoch: 108, Loss: 5.181
# Epoch: 109, Loss: 5.600
# Epoch: 110, Loss: 5.463
# Epoch: 111, Loss: 4.914
# Epoch: 112, Loss: 5.459
# Epoch: 113, Loss: 5.867
# Epoch: 114, Loss: 4.837
# Epoch: 115, Loss: 5.222
# Epoch: 116, Loss: 5.734
# Epoch: 117, Loss: 4.575
# Epoch: 118, Loss: 7.071
# Epoch: 119, Loss: 5.230
# Epoch: 120, Loss: 5.762
# Epoch: 121, Loss: 5.259
# Epoch: 122, Loss: 5.196
# Epoch: 123, Loss: 5.435
# Epoch: 124, Loss: 6.235
# Epoch: 125, Loss: 4.825
# Epoch: 126, Loss: 4.514
# Epoch: 127, Loss: 5.687
# Epoch: 128, Loss: 5.224
# Epoch: 129, Loss: 5.683
# Epoch: 130, Loss: 5.258
# Epoch: 131, Loss: 6.131
# Epoch: 132, Loss: 5.634
# Epoch: 133, Loss: 5.335
# Epoch: 134, Loss: 4.834
# Epoch: 135, Loss: 3.877
# Epoch: 136, Loss: 4.982
# Epoch: 137, Loss: 5.112
# Epoch: 138, Loss: 4.887
# Epoch: 139, Loss: 5.359
# Epoch: 140, Loss: 5.399
# Epoch: 141, Loss: 5.657
# Epoch: 142, Loss: 5.651
# Epoch: 143, Loss: 5.120
# Epoch: 144, Loss: 4.937
# Epoch: 145, Loss: 4.734
# Epoch: 146, Loss: 4.812
# Epoch: 147, Loss: 4.913
# Epoch: 148, Loss: 4.493
# Epoch: 149, Loss: 4.063
# Epoch: 150, Loss: 5.524
# Epoch: 151, Loss: 5.319
# Epoch: 152, Loss: 5.937
# Epoch: 153, Loss: 4.736
# Epoch: 154, Loss: 4.869
# Epoch: 155, Loss: 5.907
# Epoch: 156, Loss: 4.715
# Epoch: 157, Loss: 5.219
# Epoch: 158, Loss: 4.825
# Epoch: 159, Loss: 4.550
# Epoch: 160, Loss: 5.003
# Epoch: 161, Loss: 4.824
# Epoch: 162, Loss: 5.553
# Epoch: 163, Loss: 4.692
# Epoch: 164, Loss: 4.579
# Epoch: 165, Loss: 4.787
# Epoch: 166, Loss: 4.932
# Epoch: 167, Loss: 5.506
# Epoch: 168, Loss: 4.401
# Epoch: 169, Loss: 5.327
# Epoch: 170, Loss: 5.305
# Epoch: 171, Loss: 5.170
# Epoch: 172, Loss: 4.771
# Epoch: 173, Loss: 5.228
# Epoch: 174, Loss: 4.596
# Epoch: 175, Loss: 4.938
# Epoch: 176, Loss: 4.564
# Epoch: 177, Loss: 4.780
# Epoch: 178, Loss: 4.876
# Epoch: 179, Loss: 5.229
# Epoch: 180, Loss: 4.174
# Epoch: 181, Loss: 4.892
# Epoch: 182, Loss: 4.000
# Epoch: 183, Loss: 5.747
# Epoch: 184, Loss: 5.811
# Epoch: 185, Loss: 4.539
# Epoch: 186, Loss: 4.201
# Epoch: 187, Loss: 5.115
# Epoch: 188, Loss: 4.824
# Epoch: 189, Loss: 4.767
# Epoch: 190, Loss: 4.481
# Epoch: 191, Loss: 4.503
# Epoch: 192, Loss: 5.170
# Epoch: 193, Loss: 3.889
# Epoch: 194, Loss: 5.111
# Epoch: 195, Loss: 4.799
# Epoch: 196, Loss: 4.371
# Epoch: 197, Loss: 4.216
# Epoch: 198, Loss: 6.168
# Epoch: 199, Loss: 4.506
# Epoch: 200, Loss: 4.719
# Epoch: 201, Loss: 5.331
# Epoch: 202, Loss: 4.656
# Epoch: 203, Loss: 4.388
# Epoch: 204, Loss: 4.818
# Epoch: 205, Loss: 4.930
# Epoch: 206, Loss: 4.550
# Epoch: 207, Loss: 3.899
# Epoch: 208, Loss: 4.452
# Epoch: 209, Loss: 4.618
# Epoch: 210, Loss: 4.982
# Epoch: 211, Loss: 4.321
# Epoch: 212, Loss: 5.035
# Epoch: 213, Loss: 4.891
# Epoch: 214, Loss: 4.352
# Epoch: 215, Loss: 4.379
# Epoch: 216, Loss: 4.569
# Epoch: 217, Loss: 4.571
# Epoch: 218, Loss: 4.783
# Epoch: 219, Loss: 4.480
# Epoch: 220, Loss: 3.912
# Epoch: 221, Loss: 5.577
# Epoch: 222, Loss: 4.658
# Epoch: 223, Loss: 4.145
# Epoch: 224, Loss: 4.507
# Epoch: 225, Loss: 4.640
# Epoch: 226, Loss: 4.569
# Epoch: 227, Loss: 4.720
# Epoch: 228, Loss: 3.891
# Epoch: 229, Loss: 4.972
# Epoch: 230, Loss: 4.071
# Epoch: 231, Loss: 5.483
# Epoch: 232, Loss: 5.100
# Epoch: 233, Loss: 4.310
# Epoch: 234, Loss: 5.104
# Epoch: 235, Loss: 5.228
# Epoch: 236, Loss: 4.716
# Epoch: 237, Loss: 4.585
# Epoch: 238, Loss: 5.092
# Epoch: 239, Loss: 4.262
# Epoch: 240, Loss: 4.618
# Epoch: 241, Loss: 4.657
# Epoch: 242, Loss: 4.720
# Epoch: 243, Loss: 4.799
# Epoch: 244, Loss: 5.164
# Epoch: 245, Loss: 5.237
# Epoch: 246, Loss: 4.016
# Epoch: 247, Loss: 4.398
# Epoch: 248, Loss: 4.563
# Epoch: 249, Loss: 4.588
# Epoch: 250, Loss: 4.307
# Epoch: 251, Loss: 4.412
# Epoch: 252, Loss: 3.969
# Epoch: 253, Loss: 3.663
# Epoch: 254, Loss: 4.361
# Epoch: 255, Loss: 5.033
# Epoch: 256, Loss: 4.466
# Epoch: 257, Loss: 4.413
# Epoch: 258, Loss: 4.160
# Epoch: 259, Loss: 5.049
# Epoch: 260, Loss: 3.969
# Epoch: 261, Loss: 4.060
# Epoch: 262, Loss: 3.973
# Epoch: 263, Loss: 3.925
# Epoch: 264, Loss: 4.260
# Epoch: 265, Loss: 3.739
# Epoch: 266, Loss: 4.265
# Epoch: 267, Loss: 4.401
# Epoch: 268, Loss: 4.150
# Epoch: 269, Loss: 4.249
# Epoch: 270, Loss: 4.390
# Epoch: 271, Loss: 4.199
# Epoch: 272, Loss: 4.817
# Epoch: 273, Loss: 4.457
# Epoch: 274, Loss: 3.624
# Epoch: 275, Loss: 4.204
# Epoch: 276, Loss: 4.209
# Epoch: 277, Loss: 5.009
# Epoch: 278, Loss: 4.334
# Epoch: 279, Loss: 4.019
# Epoch: 280, Loss: 4.439
# Epoch: 281, Loss: 3.844
# Epoch: 282, Loss: 4.508
# Epoch: 283, Loss: 4.268
# Epoch: 284, Loss: 4.389
# Epoch: 285, Loss: 4.628
# Epoch: 286, Loss: 3.734
# Epoch: 287, Loss: 4.035
# Epoch: 288, Loss: 3.993
# Epoch: 289, Loss: 4.433
# Epoch: 290, Loss: 4.042
# Epoch: 291, Loss: 4.435
# Epoch: 292, Loss: 4.726
# Epoch: 293, Loss: 4.223
# Epoch: 294, Loss: 4.785
# Epoch: 295, Loss: 4.469
# Epoch: 296, Loss: 4.205
# Epoch: 297, Loss: 4.154
# Epoch: 298, Loss: 4.549
# Epoch: 299, Loss: 4.611
# Epoch: 300, Loss: 3.944
# Epoch: 301, Loss: 4.521
# Epoch: 302, Loss: 4.358
# Epoch: 303, Loss: 4.476
# Epoch: 304, Loss: 4.594
# Epoch: 305, Loss: 4.293
# Epoch: 306, Loss: 4.351
# Epoch: 307, Loss: 4.786
# Epoch: 308, Loss: 4.259
# Epoch: 309, Loss: 4.361
# Epoch: 310, Loss: 4.057
# Epoch: 311, Loss: 4.080
# Epoch: 312, Loss: 4.111
# Epoch: 313, Loss: 4.238
# Epoch: 314, Loss: 3.746
# Epoch: 315, Loss: 4.210
# Epoch: 316, Loss: 4.260
# Epoch: 317, Loss: 4.458
# Epoch: 318, Loss: 3.747
# Epoch: 319, Loss: 4.432
# Epoch: 320, Loss: 4.084
# Epoch: 321, Loss: 4.261
# Epoch: 322, Loss: 4.589
# Epoch: 323, Loss: 4.267
# Epoch: 324, Loss: 4.587
# Epoch: 325, Loss: 3.570
# Epoch: 326, Loss: 4.223
# Epoch: 327, Loss: 4.022
# Epoch: 328, Loss: 3.678
# Epoch: 329, Loss: 4.272
# Epoch: 330, Loss: 4.250
# Epoch: 331, Loss: 4.243
# Epoch: 332, Loss: 4.267
# Epoch: 333, Loss: 3.647
# Epoch: 334, Loss: 4.105
# Epoch: 335, Loss: 4.242
# Epoch: 336, Loss: 3.933
# Epoch: 337, Loss: 4.502
# Epoch: 338, Loss: 4.172
# Epoch: 339, Loss: 4.602
# Epoch: 340, Loss: 4.208
# Epoch: 341, Loss: 4.047
# Epoch: 342, Loss: 4.050
# Epoch: 343, Loss: 4.251
# Epoch: 344, Loss: 4.069
# Epoch: 345, Loss: 4.207
# Epoch: 346, Loss: 4.228
# Epoch: 347, Loss: 4.307
# Epoch: 348, Loss: 4.122
# Epoch: 349, Loss: 4.424
# Epoch: 350, Loss: 4.975
# Epoch: 351, Loss: 3.852
# Epoch: 352, Loss: 4.690
# Epoch: 353, Loss: 3.321
# Epoch: 354, Loss: 4.319
# Epoch: 355, Loss: 4.476
# Epoch: 356, Loss: 4.056
# Epoch: 357, Loss: 4.049
# Epoch: 358, Loss: 4.398
# Epoch: 359, Loss: 3.860
# Epoch: 360, Loss: 4.620
# Epoch: 361, Loss: 4.020
# Epoch: 362, Loss: 3.808
# Epoch: 363, Loss: 3.262
# Epoch: 364, Loss: 3.769
# Epoch: 365, Loss: 4.373
# Epoch: 366, Loss: 4.587
# Epoch: 367, Loss: 4.677
# Epoch: 368, Loss: 4.263
# Epoch: 369, Loss: 3.701
# Epoch: 370, Loss: 3.976
# Epoch: 371, Loss: 4.210
# Epoch: 372, Loss: 4.079
# Epoch: 373, Loss: 4.477
# Epoch: 374, Loss: 4.706
# Epoch: 375, Loss: 3.552
# Epoch: 376, Loss: 4.476
# Epoch: 377, Loss: 4.542
# Epoch: 378, Loss: 4.448
# Epoch: 379, Loss: 4.450
# Epoch: 380, Loss: 4.091
# Epoch: 381, Loss: 4.472
# Epoch: 382, Loss: 4.239
# Epoch: 383, Loss: 4.891
# Epoch: 384, Loss: 4.056
# Epoch: 385, Loss: 3.945
# Epoch: 386, Loss: 4.463
# Epoch: 387, Loss: 4.450
# Epoch: 388, Loss: 4.422
# Epoch: 389, Loss: 4.338
# Epoch: 390, Loss: 3.778
# Epoch: 391, Loss: 3.995
# Epoch: 392, Loss: 4.011
# Epoch: 393, Loss: 3.933
# Epoch: 394, Loss: 3.642
# Epoch: 395, Loss: 4.219
# Epoch: 396, Loss: 4.055
# Epoch: 397, Loss: 4.014
# Epoch: 398, Loss: 4.222
# Epoch: 399, Loss: 4.535
# Epoch: 400, Loss: 4.319
# Epoch: 401, Loss: 4.418
# Epoch: 402, Loss: 4.062
# Epoch: 403, Loss: 4.355
# Epoch: 404, Loss: 3.832
# Epoch: 405, Loss: 3.774
# Epoch: 406, Loss: 4.129
# Epoch: 407, Loss: 4.878
# Epoch: 408, Loss: 4.527
# Epoch: 409, Loss: 4.483
# Epoch: 410, Loss: 3.694
# Epoch: 411, Loss: 3.998
# Epoch: 412, Loss: 3.307
# Epoch: 413, Loss: 4.107
# Epoch: 414, Loss: 4.359
# Epoch: 415, Loss: 3.728
# Epoch: 416, Loss: 3.555
# Epoch: 417, Loss: 4.294
# Epoch: 418, Loss: 3.849
# Epoch: 419, Loss: 4.032
# Epoch: 420, Loss: 3.672
# Epoch: 421, Loss: 4.208
# Epoch: 422, Loss: 4.155
# Epoch: 423, Loss: 4.472
# Epoch: 424, Loss: 4.022
# Epoch: 425, Loss: 4.055
# Epoch: 426, Loss: 3.735
# Epoch: 427, Loss: 3.995
# Epoch: 428, Loss: 4.647
# Epoch: 429, Loss: 4.613
# Epoch: 430, Loss: 3.862
# Epoch: 431, Loss: 4.440
# Epoch: 432, Loss: 3.888
# Epoch: 433, Loss: 3.948
# Epoch: 434, Loss: 4.509
# Epoch: 435, Loss: 4.253
# Epoch: 436, Loss: 4.253
# Epoch: 437, Loss: 3.339
# Epoch: 438, Loss: 4.057
# Epoch: 439, Loss: 3.646
# Epoch: 440, Loss: 4.509
# Epoch: 441, Loss: 3.992
# Epoch: 442, Loss: 3.673
# Epoch: 443, Loss: 3.771
# Epoch: 444, Loss: 3.801
# Epoch: 445, Loss: 3.949
# Epoch: 446, Loss: 3.916
# Epoch: 447, Loss: 4.560
# Epoch: 448, Loss: 3.641
# Epoch: 449, Loss: 4.669
# Epoch: 450, Loss: 4.152
# Epoch: 451, Loss: 3.608
# Epoch: 452, Loss: 4.803
# Epoch: 453, Loss: 3.940
# Epoch: 454, Loss: 4.210
# Epoch: 455, Loss: 3.919
# Epoch: 456, Loss: 4.073
# Epoch: 457, Loss: 3.877
# Epoch: 458, Loss: 3.540
# Epoch: 459, Loss: 3.917
# Epoch: 460, Loss: 3.903
# Epoch: 461, Loss: 3.593
# Epoch: 462, Loss: 4.028
# Epoch: 463, Loss: 3.655
# Epoch: 464, Loss: 4.095
# Epoch: 465, Loss: 4.186
# Epoch: 466, Loss: 3.613
# Epoch: 467, Loss: 4.335
# Epoch: 468, Loss: 3.929
# Epoch: 469, Loss: 4.165
# Epoch: 470, Loss: 3.541
# Epoch: 471, Loss: 4.320
# Epoch: 472, Loss: 4.160
# Epoch: 473, Loss: 4.436
# Epoch: 474, Loss: 4.856
# Epoch: 475, Loss: 4.566
# Epoch: 476, Loss: 4.056
# Epoch: 477, Loss: 3.806
# Epoch: 478, Loss: 4.198
# Epoch: 479, Loss: 3.754
# Epoch: 480, Loss: 4.282
# Epoch: 481, Loss: 4.070
# Epoch: 482, Loss: 3.778
# Epoch: 483, Loss: 3.366
# Epoch: 484, Loss: 4.061
# Epoch: 485, Loss: 4.345
# Epoch: 486, Loss: 3.878
# Epoch: 487, Loss: 4.368
# Epoch: 488, Loss: 4.073
# Epoch: 489, Loss: 3.702
# Epoch: 490, Loss: 4.574
# Epoch: 491, Loss: 3.978
# Epoch: 492, Loss: 4.228
# Epoch: 493, Loss: 3.574
# Epoch: 494, Loss: 4.133
# Epoch: 495, Loss: 4.022
# Epoch: 496, Loss: 4.151
# Epoch: 497, Loss: 4.211
# Epoch: 498, Loss: 4.039
# Epoch: 499, Loss: 3.844
# Epoch: 500, Loss: 3.948
# Epoch: 501, Loss: 4.238
# Epoch: 502, Loss: 4.107
# Epoch: 503, Loss: 4.196
# Epoch: 504, Loss: 4.363
# Epoch: 505, Loss: 4.034
# Epoch: 506, Loss: 3.987
# Epoch: 507, Loss: 3.773
# Epoch: 508, Loss: 3.728
# Epoch: 509, Loss: 4.474
# Epoch: 510, Loss: 3.727
# Epoch: 511, Loss: 3.709
# Epoch: 512, Loss: 4.056
# Epoch: 513, Loss: 3.900
# Epoch: 514, Loss: 4.200
# Epoch: 515, Loss: 4.289
# Epoch: 516, Loss: 3.944
# Epoch: 517, Loss: 3.850
# Epoch: 518, Loss: 3.942
# Epoch: 519, Loss: 3.491
# Epoch: 520, Loss: 3.982
# Epoch: 521, Loss: 4.214
# Epoch: 522, Loss: 3.849
# Epoch: 523, Loss: 3.780
# Epoch: 524, Loss: 4.837
# Epoch: 525, Loss: 4.034
# Epoch: 526, Loss: 3.906
# Epoch: 527, Loss: 4.058
# Epoch: 528, Loss: 4.265
# Epoch: 529, Loss: 3.645
# Epoch: 530, Loss: 3.575
# Epoch: 531, Loss: 4.043
# Epoch: 532, Loss: 3.335
# Epoch: 533, Loss: 4.041
# Epoch: 534, Loss: 3.735
# Epoch: 535, Loss: 4.067
# Epoch: 536, Loss: 4.332
# Epoch: 537, Loss: 4.095
# Epoch: 538, Loss: 3.904
# Epoch: 539, Loss: 3.457
# Epoch: 540, Loss: 3.619
# Epoch: 541, Loss: 4.158
# Epoch: 542, Loss: 3.369
# Epoch: 543, Loss: 3.813
# Epoch: 544, Loss: 3.752
# Epoch: 545, Loss: 4.385
# Epoch: 546, Loss: 3.971
# Epoch: 547, Loss: 3.794
# Epoch: 548, Loss: 3.406
# Epoch: 549, Loss: 4.090
# Epoch: 550, Loss: 4.216
# Epoch: 551, Loss: 4.097
# Epoch: 552, Loss: 4.019
# Epoch: 553, Loss: 3.968
# Epoch: 554, Loss: 3.704
# Epoch: 555, Loss: 4.398
# Epoch: 556, Loss: 3.668
# Epoch: 557, Loss: 3.664
# Epoch: 558, Loss: 3.932
# Epoch: 559, Loss: 4.310
# Epoch: 560, Loss: 3.877
# Epoch: 561, Loss: 3.935
# Epoch: 562, Loss: 4.041
# Epoch: 563, Loss: 3.188
# Epoch: 564, Loss: 4.101
# Epoch: 565, Loss: 3.538
# Epoch: 566, Loss: 3.758
# Epoch: 567, Loss: 4.367
# Epoch: 568, Loss: 4.228
# Epoch: 569, Loss: 3.754
# Epoch: 570, Loss: 3.593
# Epoch: 571, Loss: 3.143
# Epoch: 572, Loss: 4.300
# Epoch: 573, Loss: 3.858
# Epoch: 574, Loss: 4.237
# Epoch: 575, Loss: 4.215
# Epoch: 576, Loss: 4.012
# Epoch: 577, Loss: 4.169
# Epoch: 578, Loss: 3.206
# Epoch: 579, Loss: 4.146
# Epoch: 580, Loss: 4.666
# Epoch: 581, Loss: 3.985
# Epoch: 582, Loss: 4.296
# Epoch: 583, Loss: 4.570
# Epoch: 584, Loss: 4.070
# Epoch: 585, Loss: 3.472
# Epoch: 586, Loss: 4.099
# Epoch: 587, Loss: 3.894
# Epoch: 588, Loss: 4.220
# Epoch: 589, Loss: 3.964
# Epoch: 590, Loss: 4.014
# Epoch: 591, Loss: 3.865
# Epoch: 592, Loss: 3.964
# Epoch: 593, Loss: 4.008
# Epoch: 594, Loss: 4.412
# Epoch: 595, Loss: 3.847
# Epoch: 596, Loss: 3.865
# Epoch: 597, Loss: 3.784
# Epoch: 598, Loss: 4.130
# Epoch: 599, Loss: 3.861
# Epoch: 600, Loss: 4.056
# Epoch: 601, Loss: 3.559
# Epoch: 602, Loss: 4.407
# Epoch: 603, Loss: 3.630
# Epoch: 604, Loss: 3.440
# Epoch: 605, Loss: 3.963
# Epoch: 606, Loss: 3.718
# Epoch: 607, Loss: 4.160
# Epoch: 608, Loss: 3.971
# Epoch: 609, Loss: 4.626
# Epoch: 610, Loss: 3.978
# Epoch: 611, Loss: 4.250
# Epoch: 612, Loss: 3.850
# Epoch: 613, Loss: 3.853
# Epoch: 614, Loss: 3.836
# Epoch: 615, Loss: 4.061
# Epoch: 616, Loss: 3.793
# Epoch: 617, Loss: 3.787
# Epoch: 618, Loss: 3.504
# Epoch: 619, Loss: 3.767
# Epoch: 620, Loss: 3.612
# Epoch: 621, Loss: 4.126
# Epoch: 622, Loss: 3.660
# Epoch: 623, Loss: 4.017
# Epoch: 624, Loss: 4.053
# Epoch: 625, Loss: 3.564
# Epoch: 626, Loss: 3.450
# Epoch: 627, Loss: 3.832
# Epoch: 628, Loss: 3.691
# Epoch: 629, Loss: 3.531
# Epoch: 630, Loss: 3.594
# Epoch: 631, Loss: 3.757
# Epoch: 632, Loss: 3.775
# Epoch: 633, Loss: 4.164
# Epoch: 634, Loss: 3.613
# Epoch: 635, Loss: 3.712
# Epoch: 636, Loss: 3.918
# Epoch: 637, Loss: 3.611
# Epoch: 638, Loss: 3.666
# Epoch: 639, Loss: 3.708
# Epoch: 640, Loss: 4.149
# Epoch: 641, Loss: 3.837
# Epoch: 642, Loss: 3.838
# Epoch: 643, Loss: 3.829
# Epoch: 644, Loss: 3.946
# Epoch: 645, Loss: 3.712
# Epoch: 646, Loss: 3.574
# Epoch: 647, Loss: 4.222
# Epoch: 648, Loss: 3.668
# Epoch: 649, Loss: 4.155
# Epoch: 650, Loss: 3.790
# Epoch: 651, Loss: 4.052
# Epoch: 652, Loss: 4.024
# Epoch: 653, Loss: 4.006
# Epoch: 654, Loss: 4.123
# Epoch: 655, Loss: 3.877
# Epoch: 656, Loss: 3.516
# Epoch: 657, Loss: 3.645
# Epoch: 658, Loss: 3.777
# Epoch: 659, Loss: 4.324
# Epoch: 660, Loss: 3.698
# Epoch: 661, Loss: 3.914
# Epoch: 662, Loss: 3.619
# Epoch: 663, Loss: 3.635
# Epoch: 664, Loss: 3.868
# Epoch: 665, Loss: 3.935
# Epoch: 666, Loss: 3.593
# Epoch: 667, Loss: 4.006
# Epoch: 668, Loss: 3.783
# Epoch: 669, Loss: 4.075
# Epoch: 670, Loss: 4.151
# Epoch: 671, Loss: 3.752
# Epoch: 672, Loss: 3.658
# Epoch: 673, Loss: 4.240
# Epoch: 674, Loss: 3.261
# Epoch: 675, Loss: 3.779
# Epoch: 676, Loss: 3.861
# Epoch: 677, Loss: 3.887
# Epoch: 678, Loss: 3.430
# Epoch: 679, Loss: 3.534
# Epoch: 680, Loss: 3.571
# Epoch: 681, Loss: 3.535
# Epoch: 682, Loss: 4.015
# Epoch: 683, Loss: 4.504
# Epoch: 684, Loss: 3.601
# Epoch: 685, Loss: 3.927
# Epoch: 686, Loss: 3.541
# Epoch: 687, Loss: 3.919
# Epoch: 688, Loss: 4.205
# Epoch: 689, Loss: 4.228
# Epoch: 690, Loss: 3.605
# Epoch: 691, Loss: 3.332
# Epoch: 692, Loss: 3.521
# Epoch: 693, Loss: 3.610
# Epoch: 694, Loss: 3.260
# Epoch: 695, Loss: 3.993
# Epoch: 696, Loss: 3.663
# Epoch: 697, Loss: 4.279
# Epoch: 698, Loss: 3.963
# Epoch: 699, Loss: 3.671
# Epoch: 700, Loss: 3.891
# Epoch: 701, Loss: 4.045
# Epoch: 702, Loss: 3.959
# Epoch: 703, Loss: 3.672
# Epoch: 704, Loss: 4.213
# Epoch: 705, Loss: 3.875
# Epoch: 706, Loss: 3.553
# Epoch: 707, Loss: 3.108
# Epoch: 708, Loss: 3.564
# Epoch: 709, Loss: 3.727
# Epoch: 710, Loss: 3.818
# Epoch: 711, Loss: 3.470
# Epoch: 712, Loss: 3.504
# Epoch: 713, Loss: 3.815
# Epoch: 714, Loss: 4.473
# Epoch: 715, Loss: 3.673
# Epoch: 716, Loss: 3.533
# Epoch: 717, Loss: 4.112
# Epoch: 718, Loss: 3.768
# Epoch: 719, Loss: 3.706
# Epoch: 720, Loss: 3.993
# Epoch: 721, Loss: 3.620
# Epoch: 722, Loss: 3.930
# Epoch: 723, Loss: 3.580
# Epoch: 724, Loss: 4.146
# Epoch: 725, Loss: 4.116
# Epoch: 726, Loss: 3.571
# Epoch: 727, Loss: 3.873
# Epoch: 728, Loss: 3.700
# Epoch: 729, Loss: 3.829
# Epoch: 730, Loss: 4.064
# Epoch: 731, Loss: 3.345
# Epoch: 732, Loss: 3.801
# Epoch: 733, Loss: 3.783
# Epoch: 734, Loss: 3.589
# Epoch: 735, Loss: 4.016
# Epoch: 736, Loss: 3.701
# Epoch: 737, Loss: 3.630
# Epoch: 738, Loss: 3.579
# Epoch: 739, Loss: 3.633
# Epoch: 740, Loss: 3.872
# Epoch: 741, Loss: 3.621
# Epoch: 742, Loss: 4.245
# Epoch: 743, Loss: 4.169
# Epoch: 744, Loss: 3.971
# Epoch: 745, Loss: 4.593
# Epoch: 746, Loss: 4.079
# Epoch: 747, Loss: 4.116
# Epoch: 748, Loss: 4.262
# Epoch: 749, Loss: 3.849
# Epoch: 750, Loss: 3.547
# Epoch: 751, Loss: 3.873
# Epoch: 752, Loss: 3.668
# Epoch: 753, Loss: 3.947
# Epoch: 754, Loss: 3.949
# Epoch: 755, Loss: 3.746
# Epoch: 756, Loss: 3.957
# Epoch: 757, Loss: 3.583
# Epoch: 758, Loss: 4.167
# Epoch: 759, Loss: 3.414
# Epoch: 760, Loss: 4.621
# Epoch: 761, Loss: 4.095
# Epoch: 762, Loss: 3.495
# Epoch: 763, Loss: 3.988
# Epoch: 764, Loss: 3.337
# Epoch: 765, Loss: 3.643
# Epoch: 766, Loss: 3.652
# Epoch: 767, Loss: 3.836
# Epoch: 768, Loss: 3.819
# Epoch: 769, Loss: 3.872
# Epoch: 770, Loss: 4.169
# Epoch: 771, Loss: 3.957
# Epoch: 772, Loss: 3.960
# Epoch: 773, Loss: 3.725
# Epoch: 774, Loss: 3.808
# Epoch: 775, Loss: 3.944
# Epoch: 776, Loss: 3.616
# Epoch: 777, Loss: 3.501
# Epoch: 778, Loss: 3.637
# Epoch: 779, Loss: 3.477
# Epoch: 780, Loss: 4.159
# Epoch: 781, Loss: 3.672
# Epoch: 782, Loss: 3.361
# Epoch: 783, Loss: 3.572
# Epoch: 784, Loss: 4.243
# Epoch: 785, Loss: 3.935
# Epoch: 786, Loss: 3.541
# Epoch: 787, Loss: 3.465
# Epoch: 788, Loss: 3.931
# Epoch: 789, Loss: 4.098
# Epoch: 790, Loss: 3.119
# Epoch: 791, Loss: 3.930
# Epoch: 792, Loss: 3.800
# Epoch: 793, Loss: 3.883
# Epoch: 794, Loss: 4.025
# Epoch: 795, Loss: 3.742
# Epoch: 796, Loss: 3.701
# Epoch: 797, Loss: 4.111
# Epoch: 798, Loss: 3.595
# Epoch: 799, Loss: 3.746
# Epoch: 800, Loss: 4.223
# Epoch: 801, Loss: 3.907
# Epoch: 802, Loss: 3.499
# Epoch: 803, Loss: 3.721
# Epoch: 804, Loss: 3.462
# Epoch: 805, Loss: 3.838
# Epoch: 806, Loss: 3.436
# Epoch: 807, Loss: 3.914
# Epoch: 808, Loss: 3.251
# Epoch: 809, Loss: 3.247
# Epoch: 810, Loss: 3.419
# Epoch: 811, Loss: 4.087
# Epoch: 812, Loss: 3.725
# Epoch: 813, Loss: 3.899
# Epoch: 814, Loss: 4.057
# Epoch: 815, Loss: 3.779
# Epoch: 816, Loss: 3.534
# Epoch: 817, Loss: 3.146
# Epoch: 818, Loss: 3.889
# Epoch: 819, Loss: 3.630
# Epoch: 820, Loss: 3.832
# Epoch: 821, Loss: 4.092
# Epoch: 822, Loss: 3.953
# Epoch: 823, Loss: 4.112
# Epoch: 824, Loss: 3.434
# Epoch: 825, Loss: 4.163
# Epoch: 826, Loss: 3.478
# Epoch: 827, Loss: 3.667
# Epoch: 828, Loss: 4.093
# Epoch: 829, Loss: 3.384
# Epoch: 830, Loss: 3.594
# Epoch: 831, Loss: 3.473
# Epoch: 832, Loss: 3.846
# Epoch: 833, Loss: 3.665
# Epoch: 834, Loss: 4.164
# Epoch: 835, Loss: 3.612
# Epoch: 836, Loss: 3.393
# Epoch: 837, Loss: 3.498
# Epoch: 838, Loss: 3.949
# Epoch: 839, Loss: 3.921
# Epoch: 840, Loss: 3.405
# Epoch: 841, Loss: 3.824
# Epoch: 842, Loss: 3.753
# Epoch: 843, Loss: 3.323
# Epoch: 844, Loss: 3.931
# Epoch: 845, Loss: 3.654
# Epoch: 846, Loss: 3.377
# Epoch: 847, Loss: 3.426
# Epoch: 848, Loss: 3.801
# Epoch: 849, Loss: 3.432
# Epoch: 850, Loss: 3.444
# Epoch: 851, Loss: 3.769
# Epoch: 852, Loss: 3.668
# Epoch: 853, Loss: 3.693
# Epoch: 854, Loss: 4.024
# Epoch: 855, Loss: 3.635
# Epoch: 856, Loss: 3.555
# Epoch: 857, Loss: 4.058
# Epoch: 858, Loss: 3.758
# Epoch: 859, Loss: 3.521
# Epoch: 860, Loss: 3.416
# Epoch: 861, Loss: 3.390
# Epoch: 862, Loss: 3.980
# Epoch: 863, Loss: 3.460
# Epoch: 864, Loss: 3.358
# Epoch: 865, Loss: 3.185
# Epoch: 866, Loss: 3.412
# Epoch: 867, Loss: 3.629
# Epoch: 868, Loss: 3.892
# Epoch: 869, Loss: 4.017
# Epoch: 870, Loss: 3.802
# Epoch: 871, Loss: 3.707
# Epoch: 872, Loss: 3.547
# Epoch: 873, Loss: 4.010
# Epoch: 874, Loss: 3.274
# Epoch: 875, Loss: 3.846
# Epoch: 876, Loss: 4.097
# Epoch: 877, Loss: 3.881
# Epoch: 878, Loss: 3.567
# Epoch: 879, Loss: 4.295
# Epoch: 880, Loss: 3.744
# Epoch: 881, Loss: 3.357
# Epoch: 882, Loss: 3.479
# Epoch: 883, Loss: 3.668
# Epoch: 884, Loss: 3.463
# Epoch: 885, Loss: 3.733
# Epoch: 886, Loss: 4.091
# Epoch: 887, Loss: 3.724
# Epoch: 888, Loss: 4.418
# Epoch: 889, Loss: 4.177
# Epoch: 890, Loss: 3.608
# Epoch: 891, Loss: 3.599
# Epoch: 892, Loss: 3.538
# Epoch: 893, Loss: 3.982
# Epoch: 894, Loss: 3.830
# Epoch: 895, Loss: 3.632
# Epoch: 896, Loss: 3.432
# Epoch: 897, Loss: 4.057
# Epoch: 898, Loss: 3.698
# Epoch: 899, Loss: 3.363
# Epoch: 900, Loss: 3.673
# Epoch: 901, Loss: 3.058
# Epoch: 902, Loss: 2.713
# Epoch: 903, Loss: 4.192
# Epoch: 904, Loss: 3.638
# Epoch: 905, Loss: 3.636
# Epoch: 906, Loss: 3.347
# Epoch: 907, Loss: 3.774
# Epoch: 908, Loss: 3.444
# Epoch: 909, Loss: 4.033
# Epoch: 910, Loss: 3.684
# Epoch: 911, Loss: 3.762
# Epoch: 912, Loss: 3.957
# Epoch: 913, Loss: 3.367
# Epoch: 914, Loss: 3.624
# Epoch: 915, Loss: 3.388
# Epoch: 916, Loss: 3.685
# Epoch: 917, Loss: 3.654
# Epoch: 918, Loss: 3.640
# Epoch: 919, Loss: 4.089
# Epoch: 920, Loss: 4.200
# Epoch: 921, Loss: 3.325
# Epoch: 922, Loss: 4.225
# Epoch: 923, Loss: 3.598
# Epoch: 924, Loss: 4.228
# Epoch: 925, Loss: 3.707
# Epoch: 926, Loss: 3.469
# Epoch: 927, Loss: 3.877
# Epoch: 928, Loss: 3.524
# Epoch: 929, Loss: 3.659
# Epoch: 930, Loss: 3.537
# Epoch: 931, Loss: 4.120
# Epoch: 932, Loss: 3.259
# Epoch: 933, Loss: 3.602
# Epoch: 934, Loss: 3.245
# Epoch: 935, Loss: 3.830
# Epoch: 936, Loss: 3.933
# Epoch: 937, Loss: 3.739
# Epoch: 938, Loss: 3.665
# Epoch: 939, Loss: 3.362
# Epoch: 940, Loss: 4.086
# Epoch: 941, Loss: 3.343
# Epoch: 942, Loss: 3.276
# Epoch: 943, Loss: 3.994
# Epoch: 944, Loss: 3.743
# Epoch: 945, Loss: 3.725
# Epoch: 946, Loss: 4.155
# Epoch: 947, Loss: 3.461
# Epoch: 948, Loss: 3.841
# Epoch: 949, Loss: 3.522
# Epoch: 950, Loss: 3.598
# Epoch: 951, Loss: 4.097
# Epoch: 952, Loss: 4.218
# Epoch: 953, Loss: 3.319
# Epoch: 954, Loss: 3.641
# Epoch: 955, Loss: 3.126
# Epoch: 956, Loss: 2.940
# Epoch: 957, Loss: 3.654
# Epoch: 958, Loss: 3.476
# Epoch: 959, Loss: 3.930
# Epoch: 960, Loss: 4.075
# Epoch: 961, Loss: 3.372
# Epoch: 962, Loss: 4.176
# Epoch: 963, Loss: 3.906
# Epoch: 964, Loss: 3.759
# Epoch: 965, Loss: 4.205
# Epoch: 966, Loss: 3.621
# Epoch: 967, Loss: 3.125
# Epoch: 968, Loss: 3.677
# Epoch: 969, Loss: 4.016
# Epoch: 970, Loss: 3.570
# Epoch: 971, Loss: 3.155
# Epoch: 972, Loss: 3.917
# Epoch: 973, Loss: 4.365
# Epoch: 974, Loss: 3.771
# Epoch: 975, Loss: 4.028
# Epoch: 976, Loss: 4.182
# Epoch: 977, Loss: 4.063
# Epoch: 978, Loss: 3.583
# Epoch: 979, Loss: 3.224
# Epoch: 980, Loss: 3.271
# Epoch: 981, Loss: 3.735
# Epoch: 982, Loss: 3.481
# Epoch: 983, Loss: 3.719
# Epoch: 984, Loss: 3.803
# Epoch: 985, Loss: 3.587
# Epoch: 986, Loss: 3.747
# Epoch: 987, Loss: 3.738
# Epoch: 988, Loss: 3.173
# Epoch: 989, Loss: 3.490
# Epoch: 990, Loss: 3.504
# Epoch: 991, Loss: 3.732
# Epoch: 992, Loss: 3.138
# Epoch: 993, Loss: 3.462
# Epoch: 994, Loss: 3.551
# Epoch: 995, Loss: 3.670
# Epoch: 996, Loss: 4.050
# Epoch: 997, Loss: 3.682
# Epoch: 998, Loss: 3.416
# Epoch: 999, Loss: 3.782
# Epoch: 1000, Loss: 3.759
